# %%
import pandas as pd

import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from matplotlib.pyplot import figure

# %%
#read in data and delete firs two rows and update header with 3rd row values
df = pd.read_excel("FrontiersDS.xlsx",sheet_name='Wide')
df = df.iloc[2:]
df = df.reset_index(drop=True)
new_header = df.iloc[0]
df = df[1:]
df.columns = new_header
df.head(50)
# Out:
# 0  Species Strain    Samples   Ethyl Acetate  Ethanol  \
# 1       SA   SA_A  SA.A_TSB_A         465374  1027715
# 2       SA   SA_A  SA.A_TSB_B         193151  1050974
# 3       SA   SA_A  SA.A_TSB_C         403286  1850391
# 4       SA   SA_A  SA.A_TSB_D         129833  5140770
# 5       SA   SA_A  SA.A_TSB_E         117105  3422557
# 6       SA   SA_B  SA.B_TSB_A         316764   914667
# 7       SA   SA_B  SA.B_TSB_B         141636   801684
# 8       SA   SA_B  SA.B_TSB_C         292548  1037912
# 9       SA   SA_B  SA.B_TSB_D              0  7091491
# 10      SA   SA_B  SA.B_TSB_E         588447  8155560
# 11      SA   SA_A  SA.A_BHI_A              0  3054748
# 12      SA   SA_A  SA.A_BHI_B              0   909704
# 13      SA   SA_A  SA.A_BHI_C              0  2419195
# 14      SA   SA_A  SA.A_BHI_D              0  3195134
# 15      SA   SA_A  SA.A_BHI_E              0  1208273
# 16      SA   SA_B  SA.B_BHI_A              0  3077081
# ...

# %%
#Data Cleaning

#replace nulls with 0

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 1 to 84
# Data columns (total 70 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Species                                        84 non-null     object
#  1   Strain                                         84 non-null     object
#  2   Samples                                        84 non-null     object
#  3    Ethyl Acetate                                 83 non-null     object
#  4   Ethanol                                        84 non-null     object
#  5   Propanoic acid, ethyl ester                    27 non-null     object
#  6   2-Pentanone                                    84 non-null     object
#  7   Decane                                         84 non-null     object
#  8   Methyl Isobutyl Ketone                         57 non-null     object
# ...

# %%
 df = df.fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 1 to 84
# Data columns (total 70 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Species                                        84 non-null     object
#  1   Strain                                         84 non-null     object
#  2   Samples                                        84 non-null     object
#  3    Ethyl Acetate                                 84 non-null     int64
#  4   Ethanol                                        84 non-null     int64
#  5   Propanoic acid, ethyl ester                    84 non-null     int64
#  6   2-Pentanone                                    84 non-null     int64
#  7   Decane                                         84 non-null     int64
#  8   Methyl Isobutyl Ketone                         84 non-null     int64
# ...

# %%
df.describe()
# Out:
# 0       Ethyl Acetate       Ethanol  Propanoic acid, ethyl ester  \
# count    8.400000e+01  8.400000e+01                    84.000000
# mean     2.036490e+05  2.028525e+06                  5782.309524
# std      3.002189e+05  2.590197e+06                 27125.922554
# min      0.000000e+00  0.000000e+00                     0.000000
# 25%      0.000000e+00  0.000000e+00                     0.000000
# 50%      8.781000e+04  1.032814e+06                     0.000000
# 75%      2.661052e+05  3.060331e+06                     0.000000
# max      1.335746e+06  1.073959e+07                175461.000000
#
# 0       2-Pentanone        Decane  Methyl Isobutyl Ketone  Amylene hydrate  \
# count  8.400000e+01  8.400000e+01            8.400000e+01        84.000000
# mean   1.064872e+06  2.768394e+05            1.480613e+05     86875.857143
# std    1.005756e+06  4.261672e+05            3.360538e+05    150817.542074
# min    0.000000e+00  0.000000e+00            0.000000e+00         0.000000
# ...

# %%
df.head()

#samples = df["Samples "].unique()
#samples

df.to_csv('clean_data.csv')

# %%
# create instance of labelencoder
labelencoder = LabelEncoder()
# Assign numerical values and store in a new column
clean_data['Species'] = labelencoder.fit_transform(clean_data['Study'])

# create instance of one-hot-encoder
enc = OneHotEncoder(handle_unknown='ignore')

# passing on Study_no column values
enc_df = pd.DataFrame(enc.fit_transform(clean_data[['Study_no']]).toarray())

# rename columns as Study names
enc_df = enc_df.rename(columns={0: 'Fridberg', 1: 'Horstmann', 2: 'Kjome', 3: 'Maia', 6: 'SteingroverInPrep', 4: 'Premkumar', 8: 'Wood', 9: 'Worthy', 5: 'Steingroever2011', 7: 'Wetzels'})

# reset index before concatenation
clean_data.reset_index(inplace=True)
enc = pd.concat([clean_data, enc_df], axis=1)
enc

# %%
strain = df["Strain"].unique()
strain
# Out:
# array(['SA_A', 'SA_B', 'PA_A', 'PA_B', 'EC_A', 'EC_B'], dtype=object)

# %%
sns.scatterplot(clusters_pca.iloc[:,0],clusters_pca.iloc[:,1], hue=processed_df.reset_index().PayScheme, palette='Set1', s=100, alpha=0.2).set_title('PCs Colour Coded by Payoff Scheme', fontsize=15)
